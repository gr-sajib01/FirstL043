# %% [markdown]
# <a href="https://colab.research.google.com/github/gr-sajib01/FirstL043/blob/main/Data%20processind%20task%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6dd034f8-6142-40e1-8c89-c711f5af2371" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6dd034f8-6142-40e1-8c89-c711f5af2371">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Dataset.csv")
df.head()
# Out:
#    Gender Race/ethnicity Parental level of education         Lunch  \
# 0  qajpPq        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   Test preparation course Math score Reading score Writing score Total Score
# 0                  zGZkOa         72            72            74         218
# 1               completed         69            90            88      999999
# 2                    none         90            95           NaN         278
# 3                    none        NaN            57          -999         148
# 4                     NaN         76          -999            75         229

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       909 non-null    object
#  1   Race/ethnicity               906 non-null    object
#  2   Parental level of education  905 non-null    object
#  3   Lunch                        904 non-null    object
#  4   Test preparation course      903 non-null    object
#  5   Math score                   910 non-null    object
#  6   Reading score                903 non-null    object
#  7   Writing score                913 non-null    object
#  8   Total Score                  912 non-null    object
# dtypes: object(9)
# memory usage: 70.5+ KB

# %%
df=df.drop_duplicates()
df.head()
# Out:
#    Gender Race/ethnicity Parental level of education         Lunch  \
# 0  qajpPq        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   Test preparation course Math score Reading score Writing score Total Score
# 0                  zGZkOa         72            72            74         218
# 1               completed         69            90            88      999999
# 2                    none         90            95           NaN         278
# 3                    none        NaN            57          -999         148
# 4                     NaN         76          -999            75         229

# %%
df.replace(999999,None,inplace=True)
df.replace(-999,None,inplace=True)
df.head()
# Out:
#    Gender Race/ethnicity Parental level of education         Lunch  \
# 0  qajpPq        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   Test preparation course Math score Reading score Writing score Total Score
# 0                  zGZkOa         72            72            74         218
# 1               completed         69            90            88      999999
# 2                    none         90            95           NaN         278
# 3                    none        NaN            57          -999         148
# 4                     NaN         76          -999            75         229

# %%
df["Math score"] = pd.to_numeric(df["Math score"], errors="coerce")

# %%
df = df[(df["Math score"] <= 100) & (df["Math score"] >= 0)]

# %%
df = df[(df["Math score"] <= 100) & (df["Math score"] >= 0)]
df.head()
# Out:
#    Gender Race/ethnicity Parental level of education     Lunch  \
# 0  qajpPq        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 4    male        group C                some college  standard
# 5  qajpPq        group B          associate's degree  standard
#
#   Test preparation course  Math score Reading score Writing score Total Score
# 0                  zGZkOa        72.0            72            74         218
# 1               completed        69.0            90            88      999999
# 2                    none        90.0            95           NaN         278
# 4                     NaN        76.0          -999            75         229
# 5                    none        71.0            83            78         232

# %%
sample_df=df.sample(n=50)
sample_df.head()
# Out:
#      Gender Race/ethnicity Parental level of education         Lunch  \
# 228    male         lK2V0z            some high school  free/reduced
# 711  female        group E            some high school      standard
# 965  female        group D                some college        TldOs7
# 308  female        group B          associate's degree  free/reduced
# 770    male        group B                 high school      standard
#
#     Test preparation course  Math score Reading score Writing score  \
# 228                    none        68.0            72            64
# 711                  zGZkOa        80.0            85            85
# 965                    none        62.0            70            72
# 308                    none        53.0            71            67
# 770                    none        52.0           NaN          -999
#
#     Total Score
# 228         204
# 711         250
# 965         204
# 308         191
# 770         149

# %%
cols = ["Math score", "Reading score", "Writing score"]
for c in cols:
    df[c] = pd.to_numeric(df[c], errors="coerce")

# %%
df["Total Score"] = df["Math score"] + df["Reading score"] + df["Writing score"]

# %%
df["Total Score"] = df["Math score"] + df["Reading score"] + df["Writing score"]
df.head()
# Out:
#    Gender Race/ethnicity Parental level of education     Lunch  \
# 0  qajpPq        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 4    male        group C                some college  standard
# 5  qajpPq        group B          associate's degree  standard
#
#   Test preparation course  Math score  Reading score  Writing score  \
# 0                  zGZkOa        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0            NaN
# 4                     NaN        76.0         -999.0           75.0
# 5                    none        71.0           83.0           78.0
#
#    Total Score
# 0        218.0
# 1        247.0
# 2          NaN
# 4       -848.0
# 5        232.0

# %%
df = df.dropna()

# %%
df.head()
# Out:
#     Gender Race/ethnicity Parental level of education         Lunch  \
# 0   qajpPq        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 5   qajpPq        group B          associate's degree      standard
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
#
#    Test preparation course  Math score  Reading score  Writing score  \
# 0                   zGZkOa        72.0           72.0           74.0
# 1                completed        69.0           90.0           88.0
# 5                     none        71.0           83.0           78.0
# 8                completed        64.0           64.0           67.0
# 10                    none        58.0           54.0           52.0
#
#     Total Score
# 0         218.0
# 1         247.0
# 5         232.0
# 8         195.0
# 10        164.0

# %%
df.to_csv("clean_dataset.csv",index=False)
